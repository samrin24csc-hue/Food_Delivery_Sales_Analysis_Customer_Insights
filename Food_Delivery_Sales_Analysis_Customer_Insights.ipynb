# %% [markdown]
# <a href="https://colab.research.google.com/github/samrin24csc-hue/Food_Delivery_Sales_Analysis_Customer_Insights/blob/main/Food_Delivery_Sales_Analysis_Customer_Insights.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

np.random.seed(42)

food_items = ['Burger', 'Pizza', 'Biryani', 'Pasta', 'Sandwich']
locations = ['Chennai', 'Madurai', 'Trichy', 'Coimbatore', 'Salem']
times = ['10 AM', '12 PM', '2 PM', '4 PM', '6 PM', '8 PM']

data = {
    'Order_ID': range(1, 201),
    'Food_Item': np.random.choice(food_items, 200),
    'Location': np.random.choice(locations, 200),
    'Order_Time': np.random.choice(times, 200),
    'Quantity': np.random.randint(1, 5, 200),
    'Price': np.random.randint(100, 500, 200)
}

df = pd.DataFrame(data)

df['Revenue'] = df['Quantity'] * df['Price']

df.to_csv('food_delivery_data.csv', index=False)

df.head()
# Out:
#    Order_ID Food_Item    Location Order_Time  Quantity  Price  Revenue
# 0         1     Pasta     Madurai       2 PM         4    402     1608
# 1         2  Sandwich      Trichy       6 PM         2    306      612
# 2         3   Biryani     Chennai       8 PM         2    328      656
# 3         4  Sandwich     Chennai      10 AM         4    440     1760
# 4         5  Sandwich  Coimbatore       6 PM         4    497     1988

# %%
print("Dataset Shape:", df.shape)
print("\nColumn Information:")
print(df.info())

print("\nSummary Statistics:")
print(df.describe())
# Out:
# Dataset Shape: (200, 7)
#
# Column Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Order_ID    200 non-null    int64
#  1   Food_Item   200 non-null    object
#  2   Location    200 non-null    object
#  3   Order_Time  200 non-null    object
#  4   Quantity    200 non-null    int64
#  5   Price       200 non-null    int64
#  6   Revenue     200 non-null    int64
# dtypes: int64(4), object(3)
# memory usage: 11.1+ KB
# None
#
# Summary Statistics:
#          Order_ID    Quantity       Price      Revenue
# count  200.000000  200.000000  200.000000   200.000000
# mean   100.500000    2.340000  290.365000   686.310000
# std     57.879185    1.166707  119.094582   483.527942
# min      1.000000    1.000000  100.000000   102.000000
# 25%     50.750000    1.000000  181.500000   315.000000
# ...

# %%
print(df.isnull().sum())
# Out:
# Order_ID      0
# Food_Item     0
# Location      0
# Order_Time    0
# Quantity      0
# Price         0
# Revenue       0
# dtype: int64

# %%
import matplotlib.pyplot as plt

food_count = df['Food_Item'].value_counts()

food_count.plot(kind='bar')
plt.title("Most Popular Food Items")
plt.xlabel("Food Item")
plt.ylabel("Orders")
plt.show()

# %%
revenue_food = df.groupby('Food_Item')['Revenue'].sum()

revenue_food.plot(kind='bar')
plt.title("Revenue by Food Item")
plt.ylabel("Revenue")
plt.show()

# %%
location_revenue = df.groupby('Location')['Revenue'].sum()

location_revenue.plot(kind='bar')
plt.title("Revenue by Location")
plt.ylabel("Revenue")
plt.show()

# %%
time_orders = df['Order_Time'].value_counts()

time_orders.plot(kind='line', marker='o')
plt.title("Orders by Time")
plt.xlabel("Order Time")
plt.ylabel("Number of Orders")
plt.show()

# %%
revenue_food.plot(kind='pie', autopct='%1.1f%%')
plt.title("Revenue Distribution")
plt.ylabel('')
plt.show()

# %%
print("BUSINESS INSIGHTS")

print("\n1. Most Popular Food Item:")
print(df['Food_Item'].value_counts().idxmax())

print("\n2. Highest Revenue Food Item:")
print(df.groupby('Food_Item')['Revenue'].sum().idxmax())

print("\n3. Highest Revenue Location:")
print(df.groupby('Location')['Revenue'].sum().idxmax())

print("\n4. Peak Order Time:")
print(df['Order_Time'].value_counts().idxmax())
# Out:
# BUSINESS INSIGHTS
#
# 1. Most Popular Food Item:
# Pasta
#
# 2. Highest Revenue Food Item:
# Pasta
#
# 3. Highest Revenue Location:
# Chennai
#
# 4. Peak Order Time:
# 6 PM

# %%
from google.colab import files

files.download('food_delivery_data.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_3775/2886575463.py in <cell line: 0>()
#       1 from google.colab import files
#       2
# ----> 3 files.download('food_delivery_data.csv')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/files.py in download(filename)
#     228   if not _os.path.exists(filename):
#     229     msg = 'Cannot find file: {}'.format(filename)
# --> 230     raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     231
#     232   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: food_delivery_data.csv

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(2, 2, figsize=(12, 8))

# Popular Food Items
df['Food_Item'].value_counts().plot(kind='bar', ax=axes[0,0])
axes[0,0].set_title('Popular Food Items')

# Revenue by Location
df.groupby('Location')['Revenue'].sum().plot(kind='bar', ax=axes[0,1])
axes[0,1].set_title('Revenue by Location')

# Orders by Time
df['Order_Time'].value_counts().plot(kind='line', marker='o', ax=axes[1,0])
axes[1,0].set_title('Orders by Time')

# Revenue Distribution
df.groupby('Food_Item')['Revenue'].sum().plot(
    kind='pie',
    autopct='%1.1f%%',
    ax=axes[1,1]
)
axes[1,1].set_title('Revenue Distribution')
axes[1,1].set_ylabel('')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3775/843008725.py in <cell line: 0>()
#       4
#       5 # Popular Food Items
# ----> 6 df['Food_Item'].value_counts().plot(kind='bar', ax=axes[0,0])
#       7 axes[0,0].set_title('Popular Food Items')
#       8
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
import numpy as np

np.random.seed(42)

food_items = ['Burger', 'Pizza', 'Biryani', 'Pasta', 'Sandwich']
locations = ['Chennai', 'Madurai', 'Trichy', 'Coimbatore', 'Salem']
times = ['10 AM', '12 PM', '2 PM', '4 PM', '6 PM', '8 PM']

data = {
    'Order_ID': range(1, 201),
    'Food_Item': np.random.choice(food_items, 200),
    'Location': np.random.choice(locations, 200),
    'Order_Time': np.random.choice(times, 200),
    'Quantity': np.random.randint(1, 5, 200),
    'Price': np.random.randint(100, 500, 200)
}

df = pd.DataFrame(data)
df['Revenue'] = df['Quantity'] * df['Price']

print(df.head())
# Out:
#    Order_ID Food_Item    Location Order_Time  Quantity  Price  Revenue
# 0         1     Pasta     Madurai       2 PM         4    402     1608
# 1         2  Sandwich      Trichy       6 PM         2    306      612
# 2         3   Biryani     Chennai       8 PM         2    328      656
# 3         4  Sandwich     Chennai      10 AM         4    440     1760
# 4         5  Sandwich  Coimbatore       6 PM         4    497     1988

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(2, 2, figsize=(12, 8))

# Popular Food Items
df['Food_Item'].value_counts().plot(kind='bar', ax=axes[0,0])
axes[0,0].set_title('Popular Food Items')

# Revenue by Location
df.groupby('Location')['Revenue'].sum().plot(kind='bar', ax=axes[0,1])
axes[0,1].set_title('Revenue by Location')

# Orders by Time
df['Order_Time'].value_counts().plot(kind='line', marker='o', ax=axes[1,0])
axes[1,0].set_title('Orders by Time')

# Revenue Distribution
df.groupby('Food_Item')['Revenue'].sum().plot(
    kind='pie',
    autopct='%1.1f%%',
    ax=axes[1,1]
)
axes[1,1].set_title('Revenue Distribution')
axes[1,1].set_ylabel('')

plt.tight_layout()
plt.show()
